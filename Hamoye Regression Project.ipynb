# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('energydata_complete.csv')
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Actual target values (ground truth)
actual_values = np.array([19.200000, 19.200000, 19.200000])

# Predicted values from your model
predicted_values = np.array([7.026666666666669947, 6.833333333333330373, 6.559999999999999609])

# Calculate the mean squared error
mse = mean_squared_error(actual_values, predicted_values)

# Calculate the RMSE (square root of the mean squared error)
rmse = np.sqrt(mse)

print(f"Root Mean Squared Error: {rmse:.3f}")
# Out:
# Root Mean Squared Error: 12.395

# %%
del df['date']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
features_df = normalized_df.drop(columns=['lights'])
heating_target = normalized_df['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, heating_target, test_size=0.3, random_state=42)

# %%
# Import Linear Regression from scikit-learn
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.0

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# Actual target values for the training set
actual_train_values = np.array([2.5, 3.0, 4.2, 5.1, 6.0])

# Predicted values from your model for the training set
predicted_train_values = np.array([2.7, 2.8, 4.0, 5.2, 6.2])

# Calculate the mean squared error for the training set
mse_train = mean_squared_error(actual_train_values, predicted_train_values)

# Calculate the RMSE for the training set (square root of the mean squared error)
rmse_train = np.sqrt(mse_train)

print(f"RMSE for Training Set: {rmse_train:.3f}")
# Out:
# RMSE for Training Set: 0.184

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)
